# %% [markdown]
# # installing dependencies.

# %%
# !pip install stable-baselines3[extra]

# %%
# !pip install gym[box2d] pyglet

# %% [markdown]
# # importing dependencies.

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# # making the environment by leveraging openai gym package.

# %%
environment_name = "LunarLander-v2"

# %%
env = gym.make(environment_name)

# %% [markdown]
# # Testing the created environment.

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-438.2409482689605
# Episode:2 Score:-205.9050931623492
# Episode:3 Score:-94.59928873956606
# Episode:4 Score:-186.84402868712232

# %% [markdown]
# # Checking the action and observation space to find the datatypes.

# %%
env.action_space.sample()
# Out:
# 3

# %%
env.observation_space.sample()
# Out:
# array([-1.0246271 ,  0.33856922, -0.37358546, -1.9458065 ,  0.00429199,
#        -0.46821773, -1.5930872 , -0.9070006 ], dtype=float32)

# %% [markdown]
# # Creating log path to file the log events with training

# %%
log_path = os.path.join('Training', 'Logs')

# %% [markdown]
# # Defining policy for the algorithm that we choose from stablebaseline3.

# %%
env =gym.make(environment_name)

model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# # Training the model.

# %%
model.learn(total_timesteps=200000)
# Out:
# Logging to Training\Logs\PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.7     |
# |    ep_rew_mean     | -173     |
# | time/              |          |
# |    fps             | 1303     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.7        |
# |    ep_rew_mean          | -155        |
# | time/                   |             |
# |    fps                  | 932         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006266501 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00558    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 630         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0088     |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.7        |
# |    ep_rew_mean          | -152        |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004086831 |
# |    clip_fraction        | 0.0083      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0228     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 365         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00342    |
# |    value_loss           | 885         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.8        |
# |    ep_rew_mean          | -172        |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012911372 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.121      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 183         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 974         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.2        |
# |    ep_rew_mean          | -163        |
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012211564 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0595     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 411         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 1.45e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -153        |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013397073 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.000668   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 122         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 373         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -145        |
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009999102 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.00136    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 367         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00596    |
# |    value_loss           | 702         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | -136        |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 8           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009875982 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.000833   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 220         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | -127        |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 9           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011195592 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 9.86e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 253         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 120          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 741          |
# |    iterations           | 10           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0066835335 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.0104      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 206          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00707     |
# |    value_loss           | 302          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | -92.9       |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 11          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005552044 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.00496     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 164         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 246         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | -88.4       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 12          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010899383 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.0474      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.2        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00722    |
# |    value_loss           | 231         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | -83         |
# | time/                   |             |
# |    fps                  | 688         |
# |    iterations           | 13          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.003249632 |
# |    clip_fraction        | 0.00537     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0636      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00434    |
# |    value_loss           | 242         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | -77.9       |
# | time/                   |             |
# |    fps                  | 671         |
# |    iterations           | 14          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008841765 |
# |    clip_fraction        | 0.0231      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 74.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00702    |
# |    value_loss           | 170         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 185          |
# |    ep_rew_mean          | -74          |
# | time/                   |              |
# |    fps                  | 662          |
# |    iterations           | 15           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0061215702 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.3         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00562     |
# |    value_loss           | 168          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 197        |
# |    ep_rew_mean          | -70.4      |
# | time/                   |            |
# |    fps                  | 648        |
# |    iterations           | 16         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00496428 |
# |    clip_fraction        | 0.0195     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.191      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 84         |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0029    |
# |    value_loss           | 218        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 212        |
# |    ep_rew_mean          | -69.4      |
# | time/                   |            |
# |    fps                  | 636        |
# |    iterations           | 17         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01497395 |
# |    clip_fraction        | 0.0993     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.418      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.9       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00884   |
# |    value_loss           | 105        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | -66.4        |
# | time/                   |              |
# |    fps                  | 624          |
# |    iterations           | 18           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0036762173 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 155          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 203          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 241         |
# |    ep_rew_mean          | -67.8       |
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 19          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005699654 |
# |    clip_fraction        | 0.0324      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 137         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00609    |
# |    value_loss           | 310         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 259          |
# |    ep_rew_mean          | -64.6        |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 20           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0077520874 |
# |    clip_fraction        | 0.0622       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.329        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00914     |
# |    value_loss           | 251          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 274         |
# |    ep_rew_mean          | -66.7       |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 21          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011406855 |
# |    clip_fraction        | 0.0964      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 79.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 292         |
# |    ep_rew_mean          | -63.5       |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 22          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005551801 |
# |    clip_fraction        | 0.00903     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | -0.145      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.5        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00412    |
# |    value_loss           | 462         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | -59.8      |
# | time/                   |            |
# |    fps                  | 594        |
# |    iterations           | 23         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01012798 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.517      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.9       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00945   |
# |    value_loss           | 76         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 320          |
# |    ep_rew_mean          | -57.8        |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 24           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0067204013 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.292        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 127          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0111      |
# |    value_loss           | 239          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 334        |
# |    ep_rew_mean          | -55        |
# | time/                   |            |
# |    fps                  | 583        |
# |    iterations           | 25         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01109346 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.615      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.7       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00838   |
# |    value_loss           | 60.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | -49.5       |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 26          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006824426 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 133         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00474    |
# |    value_loss           | 154         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 353         |
# |    ep_rew_mean          | -43.2       |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 27          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.005847998 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.3        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00548    |
# |    value_loss           | 164         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 377         |
# |    ep_rew_mean          | -39.5       |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 28          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011747158 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.992      |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.8        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 95.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 379          |
# |    ep_rew_mean          | -42.5        |
# | time/                   |              |
# |    fps                  | 569          |
# |    iterations           | 29           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0054536643 |
# |    clip_fraction        | 0.0654       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.579        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.3         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00598     |
# |    value_loss           | 69.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 391          |
# |    ep_rew_mean          | -42.9        |
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 30           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0060154153 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.439        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 101          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00563     |
# |    value_loss           | 140          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 407         |
# |    ep_rew_mean          | -40.3       |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 31          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014449485 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.903      |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.1        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 61.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 431          |
# |    ep_rew_mean          | -39.4        |
# | time/                   |              |
# |    fps                  | 550          |
# |    iterations           | 32           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0043463977 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.722        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.1         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 67.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 448          |
# |    ep_rew_mean          | -39.6        |
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 33           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0077601494 |
# |    clip_fraction        | 0.0724       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.967       |
# |    explained_variance   | 0.599        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.3         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00696     |
# |    value_loss           | 53.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 457         |
# |    ep_rew_mean          | -36.3       |
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 34          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.012376511 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.3        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00941    |
# |    value_loss           | 46.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 474         |
# |    ep_rew_mean          | -30.1       |
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 35          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009304905 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.45        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00397    |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -28.2       |
# | time/                   |             |
# |    fps                  | 529         |
# |    iterations           | 36          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017441288 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | 0.322       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.6        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00837    |
# |    value_loss           | 146         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 503          |
# |    ep_rew_mean          | -24          |
# | time/                   |              |
# |    fps                  | 526          |
# |    iterations           | 37           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0075186305 |
# |    clip_fraction        | 0.0688       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.856       |
# |    explained_variance   | 0.617        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.94         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00668     |
# |    value_loss           | 20.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 520         |
# |    ep_rew_mean          | -17.6       |
# | time/                   |             |
# |    fps                  | 526         |
# |    iterations           | 38          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.025060695 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.933      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 525         |
# |    ep_rew_mean          | -9.12       |
# | time/                   |             |
# |    fps                  | 526         |
# |    iterations           | 39          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.006913595 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.81       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.7        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 169         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 530         |
# |    ep_rew_mean          | -2.59       |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 40          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009264631 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.4        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 171         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 532         |
# |    ep_rew_mean          | 6.04        |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 41          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.006730306 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 142         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00414    |
# |    value_loss           | 274         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 525          |
# |    ep_rew_mean          | 14           |
# | time/                   |              |
# |    fps                  | 527          |
# |    iterations           | 42           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0068646017 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.922       |
# |    explained_variance   | 0.296        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.7         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 152          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 526          |
# |    ep_rew_mean          | 28.5         |
# | time/                   |              |
# |    fps                  | 527          |
# |    iterations           | 43           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0047159484 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.842       |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.6         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00413     |
# |    value_loss           | 162          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 528          |
# |    ep_rew_mean          | 37           |
# | time/                   |              |
# |    fps                  | 527          |
# |    iterations           | 44           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0038112672 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | 0.484        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 148          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 162          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 539          |
# |    ep_rew_mean          | 45.7         |
# | time/                   |              |
# |    fps                  | 527          |
# |    iterations           | 45           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0043970095 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.882       |
# |    explained_variance   | 0.644        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.3         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 84.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 544         |
# |    ep_rew_mean          | 56.2        |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 46          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.002816899 |
# |    clip_fraction        | 0.0116      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.829      |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.2        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00123    |
# |    value_loss           | 168         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 539          |
# |    ep_rew_mean          | 59.8         |
# | time/                   |              |
# |    fps                  | 526          |
# |    iterations           | 47           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0070026102 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.806       |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.4         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 89.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 533          |
# |    ep_rew_mean          | 64.4         |
# | time/                   |              |
# |    fps                  | 526          |
# |    iterations           | 48           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0037073584 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.783       |
# |    explained_variance   | 0.265        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.4         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00351     |
# |    value_loss           | 216          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 544         |
# |    ep_rew_mean          | 71          |
# | time/                   |             |
# |    fps                  | 525         |
# |    iterations           | 49          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005944097 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.878      |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.2        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 250         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 538          |
# |    ep_rew_mean          | 72.2         |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 50           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0055978764 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.857       |
# |    explained_variance   | 0.66         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40           |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0042      |
# |    value_loss           | 101          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 540         |
# |    ep_rew_mean          | 79.8        |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 51          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.007023651 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.723      |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.9        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00564    |
# |    value_loss           | 182         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 549          |
# |    ep_rew_mean          | 86.4         |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 52           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0069815954 |
# |    clip_fraction        | 0.0835       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.86        |
# |    explained_variance   | 0.602        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.2         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00493     |
# |    value_loss           | 94.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 559          |
# |    ep_rew_mean          | 93.9         |
# | time/                   |              |
# |    fps                  | 524          |
# |    iterations           | 53           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0052517573 |
# |    clip_fraction        | 0.0677       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 159          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00536     |
# |    value_loss           | 166          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 547         |
# |    ep_rew_mean          | 95.4        |
# | time/                   |             |
# |    fps                  | 525         |
# |    iterations           | 54          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.003351194 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.703      |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.9        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 111         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 538          |
# |    ep_rew_mean          | 107          |
# | time/                   |              |
# |    fps                  | 525          |
# |    iterations           | 55           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0067862617 |
# |    clip_fraction        | 0.079        |
# |    clip_range           | 0.2          |
# ...
# |    ep_len_mean          | 435          |
# |    ep_rew_mean          | 56.9         |
# | time/                   |              |
# |    fps                  | 527          |
# |    iterations           | 81           |
# |    time_elapsed         | 314          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0059772586 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.74        |
# |    explained_variance   | 0.724        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.3         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00426     |
# |    value_loss           | 107          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | 51.6        |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 82          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.006609842 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.741      |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 147         |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00732    |
# |    value_loss           | 173         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 416          |
# |    ep_rew_mean          | 48.9         |
# | time/                   |              |
# |    fps                  | 528          |
# |    iterations           | 83           |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0072578248 |
# |    clip_fraction        | 0.0783       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.2         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 174          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | 55.7        |
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 84          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.004185763 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.7        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00362    |
# |    value_loss           | 183         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 405       |
# |    ep_rew_mean          | 59.1      |
# | time/                   |           |
# |    fps                  | 528       |
# |    iterations           | 85        |
# |    time_elapsed         | 329       |
# |    total_timesteps      | 174080    |
# | train/                  |           |
# |    approx_kl            | 0.0039463 |
# |    clip_fraction        | 0.0258    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.721    |
# |    explained_variance   | 0.721     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 37.3      |
# |    n_updates            | 840       |
# |    policy_gradient_loss | -0.00312  |
# |    value_loss           | 162       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 401         |
# |    ep_rew_mean          | 59.8        |
# | time/                   |             |
# |    fps                  | 529         |
# |    iterations           | 86          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.003876922 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.705      |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 197         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 401          |
# |    ep_rew_mean          | 66.2         |
# | time/                   |              |
# |    fps                  | 529          |
# |    iterations           | 87           |
# |    time_elapsed         | 336          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0053825337 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 0.687        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.4         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00575     |
# |    value_loss           | 178          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 394          |
# |    ep_rew_mean          | 71.4         |
# | time/                   |              |
# |    fps                  | 529          |
# |    iterations           | 88           |
# |    time_elapsed         | 340          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0039036507 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.638       |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.3         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00385     |
# |    value_loss           | 138          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 391         |
# |    ep_rew_mean          | 75.1        |
# | time/                   |             |
# |    fps                  | 530         |
# |    iterations           | 89          |
# |    time_elapsed         | 343         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.004531881 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.747      |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 183         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 385          |
# |    ep_rew_mean          | 70.6         |
# | time/                   |              |
# |    fps                  | 530          |
# |    iterations           | 90           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0074078985 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.737       |
# |    explained_variance   | 0.583        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.3         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 177          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 383          |
# |    ep_rew_mean          | 81.5         |
# | time/                   |              |
# |    fps                  | 531          |
# |    iterations           | 91           |
# |    time_elapsed         | 350          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0039088014 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.727       |
# |    explained_variance   | 0.517        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 105          |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 259          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 382          |
# |    ep_rew_mean          | 88.7         |
# | time/                   |              |
# |    fps                  | 531          |
# |    iterations           | 92           |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0046494193 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.9         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 65.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 388         |
# |    ep_rew_mean          | 95.9        |
# | time/                   |             |
# |    fps                  | 531         |
# |    iterations           | 93          |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.003674197 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.702      |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.5        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 132         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 391          |
# |    ep_rew_mean          | 95.5         |
# | time/                   |              |
# |    fps                  | 531          |
# |    iterations           | 94           |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0048189554 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.636       |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.6         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.00518     |
# |    value_loss           | 72.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 394         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 532         |
# |    iterations           | 95          |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.036581777 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 50.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 388          |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 532          |
# |    iterations           | 96           |
# |    time_elapsed         | 369          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0050870692 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.789       |
# |    explained_variance   | 0.583        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.3         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 156          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 533         |
# |    iterations           | 97          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.012627771 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.817      |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.5        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 185         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 382          |
# |    ep_rew_mean          | 111          |
# | time/                   |              |
# |    fps                  | 533          |
# |    iterations           | 98           |
# |    time_elapsed         | 376          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0049825283 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.736       |
# |    explained_variance   | 0.728        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56.4         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.005       |
# |    value_loss           | 161          |
# ------------------------------------------

# %% [markdown]
# # Creating directories to save trained model weights.

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_model_spaceInvaders')

# %%
PPO_path
# Out:
# 'Training\\Saved Models\\PPO_model_spaceInvaders'

# %%
print("current working directories", os.getcwd())
# Out:
# current working directories C:\Users\Admin

# %%
model.save(PPO_path)

# %% [markdown]
# # Loading the model weights locally.

# %%
model = PPO.load(PPO_path, env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# # Evaluating the model.

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\Admin\anaconda31\envs\baseai\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (146.43869719350823, 101.40515714233662)

# %%
env.close()

# %% [markdown]
# # Testing the performance of the model.

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break
# Out:
# info {}

# %%
env.close()

# %% [markdown]
# # Viewing the training performance in the tensorboard.

# %%
training_log_path = os.path.join(log_path, 'PPO_3')

# %%
# !tensorboard --logdir={training_log_path}
